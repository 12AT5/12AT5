# %%
import csv
from collections import deque
from datetime import datetime

def parse_time_stamp(dt_str):
    """
    Parse a timestamp string of the form: "YYYY-MM-DD HH:MM:SS.sss",
    e.g. "2024-12-01 23:16:50.000",
    into a float representing seconds from the Unix epoch (1970-01-01).
    """
    # For example: "2024-12-01 23:16:50.000"
    # We'll parse with strptime:
    #   year-month-day space hour:minute:second.micro
    dt = datetime.strptime(dt_str, "%Y-%m-%d %H:%M:%S.%f")
    # Convert to a numeric (float) timestamp
    return dt.timestamp()

def load_and_sort_activity_logs(input_csv='activity_logs.csv',
                                output_csv='activity_logs_sorted.csv'):
    """
    Reads activity_logs.csv with columns:
      user_id, computer_id, timestamp
    The timestamp is "YYYY-MM-DD HH:MM:SS.sss".
    Skips header, parse time to numeric, sorts, writes local sorted CSV.
    Returns a list of (user_id, computer_id, original_ts, numeric_time).
    """
    unsorted_rows = []
    with open(input_csv, 'r', newline='') as f_in:
        reader = csv.reader(f_in)
        # Skip the header row
        header = next(reader, None)
        
        for row in reader:
            if not row:
                continue
            user_id, computer_id, dt_str = row
            t_val = parse_time_stamp(dt_str)
            unsorted_rows.append((user_id, computer_id, dt_str, t_val))

    # Sort by t_val
    unsorted_rows.sort(key=lambda x: x[3])

    # Write out a local copy
    with open(output_csv, 'w', newline='') as f_out:
        writer = csv.writer(f_out)
        # Re-write a header if desired
        writer.writerow(["user_id","computer_id","timestamp"])
        for (u, c, original_ts, numeric_time) in unsorted_rows:
            writer.writerow([u, c, original_ts])

    return unsorted_rows

def load_and_sort_access_logs(input_csv='access_logs.csv',
                              output_csv='access_logs_sorted.csv'):
    """
    Reads access_logs.csv with columns:
      user_id, activity_type, affected_user_id, timestamp
    The timestamp is "YYYY-MM-DD HH:MM:SS.sss".
    Skips header, parse time to numeric, sorts, writes local copy.
    Returns a list of (user_id, activity_type, affected_user_id, original_ts, numeric_time).
    """
    unsorted_rows = []
    with open(input_csv, 'r', newline='') as f_in:
        reader = csv.reader(f_in)
        # skip header
        header = next(reader, None)

        for row in reader:
            if not row:
                continue
            user_id, activity_type, aff_user, dt_str = row
            t_val = parse_time_stamp(dt_str)
            unsorted_rows.append((user_id, activity_type, aff_user, dt_str, t_val))

    unsorted_rows.sort(key=lambda x: x[4])

    with open(output_csv, 'w', newline='') as f_out:
        writer = csv.writer(f_out)
        writer.writerow(["user_id","activity_type","affected_user_id","timestamp"])
        for (u, act_type, auser, original_ts, numeric_time) in unsorted_rows:
            writer.writerow([u, act_type, auser, original_ts])

    return unsorted_rows

def suspicious_bfs(activity_sorted, access_sorted, starting_user='u1'):
    """
    BFS demonstration using the sorted logs.
    We build:
      user->set of computers  (from activity_sorted)
      user->list of suspicious actions (from access_sorted)

    Then if a user performed certain suspicious activity types,
    we consider them suspicious, see which computers they used, etc.
    """
    # Build user->set of computers
    user2computers = {}
    for (u, c, dt_str, numeric_time) in activity_sorted:
        user2computers.setdefault(u, set()).add(c)

    # Build user->list of suspicious actions
    user2accesses = {}
    for (u, act_type, aff_user, dt_str, numeric_time) in access_sorted:
        user2accesses.setdefault(u, []).append((act_type, aff_user, dt_str, numeric_time))

    queue = deque([starting_user])
    visited_users = set()
    visited_computers = set()

    event_log = []
    final_susp_users = {starting_user}
    final_susp_comps = set()

    suspicious_types = {"UNAUTHORIZED_ACCESS", "MALWARE_ALERT", "DATA_EXFILTRATION"}

    while queue:
        current_u = queue.popleft()
        if current_u in visited_users:
            continue
        visited_users.add(current_u)
        event_log.append(f"Processing user: {current_u}")

        # For each computer that 'current_u' touched
        comps = user2computers.get(current_u, [])
        for c in comps:
            if c not in visited_computers:
                visited_computers.add(c)
                final_susp_comps.add(c)
                event_log.append(f"  Checking computer: {c}")

                # naive approach: any user with suspicious activity type => suspicious
                for other_user, logs in user2accesses.items():
                    for (act_type, affu, ts_s, ntime) in logs:
                        if act_type in suspicious_types:
                            if other_user not in visited_users:
                                final_susp_users.add(other_user)
                                queue.append(other_user)
                                event_log.append(f"    Found suspicious user: {other_user} => {act_type}")
    return event_log, final_susp_users, final_susp_comps

def main():
    # 1) Sort
    activity_sorted = load_and_sort_activity_logs('activity_logs.csv', 'activity_logs_sorted.csv')
    access_sorted   = load_and_sort_access_logs('access_logs.csv', 'access_logs_sorted.csv')



    #activity_sorted = load_and_sort_activity_logs('activity.csv', 'activity_sorted.csv')
    #access_sorted   = load_and_sort_access_logs('access.csv', 'access_sorted.csv')
    print("Sorted CSVs: activity_logs_sorted.csv, access_logs_sorted.csv created.")

    # 2) BFS approach
    logs, sus_users, sus_comps = suspicious_bfs(activity_sorted, access_sorted, starting_user='U1')

    # 3) Print BFS logs
    print("\n--- BFS LOGS ---")
    for line in logs:
        print(line)

    # 4) Summaries
    print("\nSuspicious users:", sus_users)
    print("Suspicious computers:", sus_comps)

if __name__ == "__main__":
    main()
# Out:
# Sorted CSVs: activity_logs_sorted.csv, access_logs_sorted.csv created.
#
# --- BFS LOGS ---
# Processing user: U1
#   Checking computer: C34
#     Found suspicious user: C18 => DATA_EXFILTRATION
#     Found suspicious user: C18 => DATA_EXFILTRATION
#     Found suspicious user: C18 => MALWARE_ALERT
#     Found suspicious user: C18 => DATA_EXFILTRATION
#     Found suspicious user: C18 => MALWARE_ALERT
#     Found suspicious user: C18 => DATA_EXFILTRATION
#     Found suspicious user: C18 => MALWARE_ALERT
#     Found suspicious user: C18 => DATA_EXFILTRATION
#     Found suspicious user: C18 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C18 => MALWARE_ALERT
#     Found suspicious user: C18 => DATA_EXFILTRATION
#     Found suspicious user: C18 => MALWARE_ALERT
#     Found suspicious user: C18 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C18 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C18 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C18 => MALWARE_ALERT
#     Found suspicious user: C18 => MALWARE_ALERT
#     Found suspicious user: C18 => DATA_EXFILTRATION
#     Found suspicious user: C18 => MALWARE_ALERT
#     Found suspicious user: C18 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C18 => MALWARE_ALERT
#     Found suspicious user: C18 => MALWARE_ALERT
#     Found suspicious user: C4 => MALWARE_ALERT
#     Found suspicious user: C4 => MALWARE_ALERT
#     Found suspicious user: C4 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C4 => DATA_EXFILTRATION
#     Found suspicious user: C4 => DATA_EXFILTRATION
#     Found suspicious user: C4 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C4 => DATA_EXFILTRATION
#     Found suspicious user: C4 => DATA_EXFILTRATION
#     Found suspicious user: C4 => MALWARE_ALERT
#     Found suspicious user: C4 => DATA_EXFILTRATION
#     Found suspicious user: C4 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C4 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C4 => MALWARE_ALERT
#     Found suspicious user: C4 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C4 => DATA_EXFILTRATION
#     Found suspicious user: C4 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C4 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C4 => MALWARE_ALERT
#     Found suspicious user: C4 => MALWARE_ALERT
#     Found suspicious user: C4 => DATA_EXFILTRATION
#     Found suspicious user: C4 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C4 => MALWARE_ALERT
#     Found suspicious user: C4 => DATA_EXFILTRATION
#     Found suspicious user: C4 => MALWARE_ALERT
#     Found suspicious user: C4 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C4 => MALWARE_ALERT
#     Found suspicious user: C4 => MALWARE_ALERT
#     Found suspicious user: C4 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C4 => MALWARE_ALERT
#     Found suspicious user: C4 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C4 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C4 => DATA_EXFILTRATION
#     Found suspicious user: C12 => DATA_EXFILTRATION
#     Found suspicious user: C12 => DATA_EXFILTRATION
#     Found suspicious user: C12 => MALWARE_ALERT
#     Found suspicious user: C12 => MALWARE_ALERT
#     Found suspicious user: C12 => DATA_EXFILTRATION
#     Found suspicious user: C12 => MALWARE_ALERT
#     Found suspicious user: C12 => DATA_EXFILTRATION
#     Found suspicious user: C12 => MALWARE_ALERT
#     Found suspicious user: C12 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C12 => MALWARE_ALERT
#     Found suspicious user: C12 => DATA_EXFILTRATION
#     Found suspicious user: C12 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C12 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C12 => MALWARE_ALERT
#     Found suspicious user: C12 => DATA_EXFILTRATION
#     Found suspicious user: C12 => MALWARE_ALERT
#     Found suspicious user: C12 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C12 => DATA_EXFILTRATION
#     Found suspicious user: C12 => DATA_EXFILTRATION
#     Found suspicious user: C12 => DATA_EXFILTRATION
#     Found suspicious user: C12 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C12 => MALWARE_ALERT
#     Found suspicious user: C12 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C12 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C12 => DATA_EXFILTRATION
#     Found suspicious user: C12 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C12 => DATA_EXFILTRATION
#     Found suspicious user: C12 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C12 => MALWARE_ALERT
#     Found suspicious user: C12 => MALWARE_ALERT
#     Found suspicious user: C12 => MALWARE_ALERT
#     Found suspicious user: C12 => DATA_EXFILTRATION
#     Found suspicious user: C12 => DATA_EXFILTRATION
#     Found suspicious user: C12 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C12 => DATA_EXFILTRATION
#     Found suspicious user: C12 => DATA_EXFILTRATION
#     Found suspicious user: C12 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C12 => MALWARE_ALERT
#     Found suspicious user: C16 => MALWARE_ALERT
#     Found suspicious user: C16 => DATA_EXFILTRATION
#     Found suspicious user: C16 => DATA_EXFILTRATION
#     Found suspicious user: C16 => DATA_EXFILTRATION
#     Found suspicious user: C16 => DATA_EXFILTRATION
#     Found suspicious user: C16 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C16 => DATA_EXFILTRATION
#     Found suspicious user: C16 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C16 => MALWARE_ALERT
#     Found suspicious user: C16 => DATA_EXFILTRATION
#     Found suspicious user: C16 => DATA_EXFILTRATION
#     Found suspicious user: C16 => DATA_EXFILTRATION
#     Found suspicious user: C16 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C16 => DATA_EXFILTRATION
#     Found suspicious user: C16 => DATA_EXFILTRATION
#     Found suspicious user: C16 => DATA_EXFILTRATION
#     Found suspicious user: C16 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C16 => DATA_EXFILTRATION
#     Found suspicious user: C16 => DATA_EXFILTRATION
#     Found suspicious user: C16 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C16 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C16 => MALWARE_ALERT
#     Found suspicious user: C16 => MALWARE_ALERT
#     Found suspicious user: C16 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C16 => MALWARE_ALERT
#     Found suspicious user: C16 => MALWARE_ALERT
#     Found suspicious user: C16 => DATA_EXFILTRATION
#     Found suspicious user: C16 => MALWARE_ALERT
#     Found suspicious user: C16 => DATA_EXFILTRATION
#     Found suspicious user: C16 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C16 => DATA_EXFILTRATION
#     Found suspicious user: C16 => DATA_EXFILTRATION
#     Found suspicious user: C16 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C16 => DATA_EXFILTRATION
#     Found suspicious user: C16 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C16 => MALWARE_ALERT
#     Found suspicious user: C16 => MALWARE_ALERT
#     Found suspicious user: C40 => MALWARE_ALERT
#     Found suspicious user: C40 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C40 => MALWARE_ALERT
#     Found suspicious user: C40 => MALWARE_ALERT
#     Found suspicious user: C40 => DATA_EXFILTRATION
#     Found suspicious user: C40 => MALWARE_ALERT
#     Found suspicious user: C40 => DATA_EXFILTRATION
#     Found suspicious user: C40 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C40 => MALWARE_ALERT
#     Found suspicious user: C40 => MALWARE_ALERT
#     Found suspicious user: C40 => DATA_EXFILTRATION
#     Found suspicious user: C40 => DATA_EXFILTRATION
#     Found suspicious user: C40 => DATA_EXFILTRATION
#     Found suspicious user: C40 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C40 => DATA_EXFILTRATION
#     Found suspicious user: C40 => MALWARE_ALERT
#     Found suspicious user: C40 => MALWARE_ALERT
#     Found suspicious user: C40 => DATA_EXFILTRATION
#     Found suspicious user: C40 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C40 => DATA_EXFILTRATION
#     Found suspicious user: C40 => DATA_EXFILTRATION
#     Found suspicious user: C40 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C40 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C40 => MALWARE_ALERT
#     Found suspicious user: C40 => MALWARE_ALERT
#     Found suspicious user: C48 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C48 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C48 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C48 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C48 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C48 => DATA_EXFILTRATION
#     Found suspicious user: C48 => MALWARE_ALERT
#     Found suspicious user: C48 => MALWARE_ALERT
#     Found suspicious user: C48 => DATA_EXFILTRATION
#     Found suspicious user: C48 => MALWARE_ALERT
#     Found suspicious user: C48 => DATA_EXFILTRATION
#     Found suspicious user: C48 => DATA_EXFILTRATION
#     Found suspicious user: C48 => MALWARE_ALERT
#     Found suspicious user: C48 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C48 => DATA_EXFILTRATION
#     Found suspicious user: C48 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C48 => DATA_EXFILTRATION
#     Found suspicious user: C48 => DATA_EXFILTRATION
#     Found suspicious user: C48 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C48 => MALWARE_ALERT
#     Found suspicious user: C48 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C48 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C34 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C34 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C34 => DATA_EXFILTRATION
#     Found suspicious user: C34 => MALWARE_ALERT
#     Found suspicious user: C34 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C34 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C34 => MALWARE_ALERT
#     Found suspicious user: C34 => DATA_EXFILTRATION
#     Found suspicious user: C34 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C34 => DATA_EXFILTRATION
#     Found suspicious user: C34 => MALWARE_ALERT
#     Found suspicious user: C34 => DATA_EXFILTRATION
#     Found suspicious user: C34 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C34 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C34 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C34 => MALWARE_ALERT
#     Found suspicious user: C34 => MALWARE_ALERT
#     Found suspicious user: C34 => DATA_EXFILTRATION
#     Found suspicious user: C34 => DATA_EXFILTRATION
#     Found suspicious user: C34 => DATA_EXFILTRATION
#     Found suspicious user: C34 => DATA_EXFILTRATION
#     Found suspicious user: C34 => MALWARE_ALERT
#     Found suspicious user: C34 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C34 => DATA_EXFILTRATION
#     Found suspicious user: C34 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C34 => MALWARE_ALERT
#     Found suspicious user: C34 => MALWARE_ALERT
#     Found suspicious user: C34 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C34 => MALWARE_ALERT
#     Found suspicious user: C34 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C34 => DATA_EXFILTRATION
#     Found suspicious user: C34 => DATA_EXFILTRATION
#     Found suspicious user: C34 => DATA_EXFILTRATION
#     Found suspicious user: C34 => DATA_EXFILTRATION
#     Found suspicious user: C34 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C34 => MALWARE_ALERT
#     Found suspicious user: C34 => DATA_EXFILTRATION
#     Found suspicious user: C34 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C21 => MALWARE_ALERT
#     Found suspicious user: C21 => MALWARE_ALERT
#     Found suspicious user: C21 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C21 => DATA_EXFILTRATION
#     Found suspicious user: C21 => MALWARE_ALERT
#     Found suspicious user: C21 => DATA_EXFILTRATION
#     Found suspicious user: C21 => MALWARE_ALERT
#     Found suspicious user: C21 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C21 => DATA_EXFILTRATION
#     Found suspicious user: C21 => MALWARE_ALERT
#     Found suspicious user: C21 => DATA_EXFILTRATION
#     Found suspicious user: C21 => DATA_EXFILTRATION
#     Found suspicious user: C21 => DATA_EXFILTRATION
#     Found suspicious user: C21 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C21 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C21 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C21 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C21 => DATA_EXFILTRATION
#     Found suspicious user: C21 => MALWARE_ALERT
#     Found suspicious user: C21 => MALWARE_ALERT
#     Found suspicious user: C21 => DATA_EXFILTRATION
#     Found suspicious user: C21 => MALWARE_ALERT
#     Found suspicious user: C21 => DATA_EXFILTRATION
#     Found suspicious user: C21 => DATA_EXFILTRATION
#     Found suspicious user: C21 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C21 => MALWARE_ALERT
#     Found suspicious user: C21 => DATA_EXFILTRATION
#     Found suspicious user: C21 => MALWARE_ALERT
#     Found suspicious user: C21 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C21 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C21 => DATA_EXFILTRATION
#     Found suspicious user: C21 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C21 => DATA_EXFILTRATION
#     Found suspicious user: C21 => DATA_EXFILTRATION
#     Found suspicious user: C21 => MALWARE_ALERT
#     Found suspicious user: C21 => MALWARE_ALERT
#     Found suspicious user: C21 => DATA_EXFILTRATION
#     Found suspicious user: C21 => MALWARE_ALERT
#     Found suspicious user: C21 => DATA_EXFILTRATION
#     Found suspicious user: C21 => DATA_EXFILTRATION
#     Found suspicious user: C21 => DATA_EXFILTRATION
#     Found suspicious user: C21 => MALWARE_ALERT
#     Found suspicious user: C21 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C21 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C14 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C14 => DATA_EXFILTRATION
#     Found suspicious user: C14 => DATA_EXFILTRATION
#     Found suspicious user: C14 => DATA_EXFILTRATION
#     Found suspicious user: C14 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C14 => MALWARE_ALERT
#     Found suspicious user: C14 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C14 => DATA_EXFILTRATION
#     Found suspicious user: C14 => MALWARE_ALERT
#     Found suspicious user: C14 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C14 => DATA_EXFILTRATION
#     Found suspicious user: C14 => DATA_EXFILTRATION
#     Found suspicious user: C14 => MALWARE_ALERT
#     Found suspicious user: C14 => MALWARE_ALERT
#     Found suspicious user: C14 => MALWARE_ALERT
#     Found suspicious user: C14 => DATA_EXFILTRATION
#     Found suspicious user: C14 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C14 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C14 => MALWARE_ALERT
#     Found suspicious user: C14 => MALWARE_ALERT
#     Found suspicious user: C14 => MALWARE_ALERT
#     Found suspicious user: C14 => DATA_EXFILTRATION
#     Found suspicious user: C14 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C36 => DATA_EXFILTRATION
#     Found suspicious user: C36 => MALWARE_ALERT
#     Found suspicious user: C36 => DATA_EXFILTRATION
#     Found suspicious user: C36 => MALWARE_ALERT
#     Found suspicious user: C36 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C36 => DATA_EXFILTRATION
#     Found suspicious user: C36 => MALWARE_ALERT
#     Found suspicious user: C36 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C36 => DATA_EXFILTRATION
#     Found suspicious user: C36 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C36 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C36 => DATA_EXFILTRATION
#     Found suspicious user: C36 => DATA_EXFILTRATION
#     Found suspicious user: C36 => MALWARE_ALERT
#     Found suspicious user: C36 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C36 => MALWARE_ALERT
#     Found suspicious user: C36 => DATA_EXFILTRATION
#     Found suspicious user: C36 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C36 => DATA_EXFILTRATION
#     Found suspicious user: C36 => MALWARE_ALERT
#     Found suspicious user: C36 => MALWARE_ALERT
#     Found suspicious user: C36 => DATA_EXFILTRATION
#     Found suspicious user: C36 => DATA_EXFILTRATION
#     Found suspicious user: C36 => DATA_EXFILTRATION
#     Found suspicious user: C36 => DATA_EXFILTRATION
#     Found suspicious user: C36 => DATA_EXFILTRATION
#     Found suspicious user: C36 => DATA_EXFILTRATION
#     Found suspicious user: C36 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C36 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C36 => MALWARE_ALERT
#     Found suspicious user: C36 => DATA_EXFILTRATION
#     Found suspicious user: C36 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C36 => DATA_EXFILTRATION
#     Found suspicious user: C36 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C25 => MALWARE_ALERT
#     Found suspicious user: C25 => DATA_EXFILTRATION
#     Found suspicious user: C25 => DATA_EXFILTRATION
#     Found suspicious user: C25 => DATA_EXFILTRATION
#     Found suspicious user: C25 => MALWARE_ALERT
#     Found suspicious user: C25 => DATA_EXFILTRATION
#     Found suspicious user: C25 => DATA_EXFILTRATION
#     Found suspicious user: C25 => DATA_EXFILTRATION
#     Found suspicious user: C25 => DATA_EXFILTRATION
#     Found suspicious user: C25 => MALWARE_ALERT
#     Found suspicious user: C25 => DATA_EXFILTRATION
#     Found suspicious user: C25 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C25 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C25 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C25 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C25 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C25 => DATA_EXFILTRATION
#     Found suspicious user: C25 => MALWARE_ALERT
#     Found suspicious user: C25 => MALWARE_ALERT
#     Found suspicious user: C25 => MALWARE_ALERT
#     Found suspicious user: C25 => DATA_EXFILTRATION
#     Found suspicious user: C25 => MALWARE_ALERT
#     Found suspicious user: C25 => MALWARE_ALERT
#     Found suspicious user: C25 => MALWARE_ALERT
#     Found suspicious user: C25 => MALWARE_ALERT
#     Found suspicious user: C25 => MALWARE_ALERT
#     Found suspicious user: C25 => DATA_EXFILTRATION
#     Found suspicious user: C25 => DATA_EXFILTRATION
#     Found suspicious user: C25 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C25 => DATA_EXFILTRATION
#     Found suspicious user: C25 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C25 => MALWARE_ALERT
#     Found suspicious user: C37 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C37 => MALWARE_ALERT
#     Found suspicious user: C37 => DATA_EXFILTRATION
#     Found suspicious user: C37 => DATA_EXFILTRATION
#     Found suspicious user: C37 => MALWARE_ALERT
#     Found suspicious user: C37 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C37 => MALWARE_ALERT
#     Found suspicious user: C37 => MALWARE_ALERT
#     Found suspicious user: C37 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C37 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C37 => DATA_EXFILTRATION
#     Found suspicious user: C37 => DATA_EXFILTRATION
#     Found suspicious user: C37 => DATA_EXFILTRATION
#     Found suspicious user: C37 => MALWARE_ALERT
#     Found suspicious user: C37 => MALWARE_ALERT
#     Found suspicious user: C37 => MALWARE_ALERT
#     Found suspicious user: C37 => DATA_EXFILTRATION
#     Found suspicious user: C37 => MALWARE_ALERT
#     Found suspicious user: C37 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C37 => MALWARE_ALERT
#     Found suspicious user: C37 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C37 => DATA_EXFILTRATION
#     Found suspicious user: C37 => MALWARE_ALERT
#     Found suspicious user: C37 => DATA_EXFILTRATION
#     Found suspicious user: C37 => DATA_EXFILTRATION
#     Found suspicious user: C37 => DATA_EXFILTRATION
#     Found suspicious user: C5 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C5 => DATA_EXFILTRATION
#     Found suspicious user: C5 => MALWARE_ALERT
#     Found suspicious user: C5 => MALWARE_ALERT
#     Found suspicious user: C5 => MALWARE_ALERT
#     Found suspicious user: C5 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C5 => MALWARE_ALERT
#     Found suspicious user: C5 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C5 => MALWARE_ALERT
#     Found suspicious user: C5 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C5 => MALWARE_ALERT
#     Found suspicious user: C5 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C5 => DATA_EXFILTRATION
#     Found suspicious user: C5 => DATA_EXFILTRATION
#     Found suspicious user: C5 => DATA_EXFILTRATION
#     Found suspicious user: C5 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C5 => DATA_EXFILTRATION
#     Found suspicious user: C5 => DATA_EXFILTRATION
#     Found suspicious user: C5 => MALWARE_ALERT
#     Found suspicious user: C5 => MALWARE_ALERT
#     Found suspicious user: C5 => DATA_EXFILTRATION
#     Found suspicious user: C5 => DATA_EXFILTRATION
#     Found suspicious user: C5 => MALWARE_ALERT
#     Found suspicious user: C8 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C8 => MALWARE_ALERT
#     Found suspicious user: C8 => MALWARE_ALERT
#     Found suspicious user: C8 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C8 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C8 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C8 => MALWARE_ALERT
#     Found suspicious user: C8 => MALWARE_ALERT
#     Found suspicious user: C8 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C8 => MALWARE_ALERT
#     Found suspicious user: C8 => MALWARE_ALERT
#     Found suspicious user: C8 => MALWARE_ALERT
#     Found suspicious user: C8 => MALWARE_ALERT
#     Found suspicious user: C8 => MALWARE_ALERT
#     Found suspicious user: C8 => DATA_EXFILTRATION
#     Found suspicious user: C8 => MALWARE_ALERT
#     Found suspicious user: C8 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C8 => DATA_EXFILTRATION
#     Found suspicious user: C8 => MALWARE_ALERT
#     Found suspicious user: C8 => DATA_EXFILTRATION
#     Found suspicious user: C8 => DATA_EXFILTRATION
#     Found suspicious user: C8 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C8 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C8 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C8 => MALWARE_ALERT
#     Found suspicious user: C8 => DATA_EXFILTRATION
#     Found suspicious user: C8 => MALWARE_ALERT
#     Found suspicious user: C8 => MALWARE_ALERT
#     Found suspicious user: C8 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C8 => DATA_EXFILTRATION
#     Found suspicious user: C8 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C8 => DATA_EXFILTRATION
#     Found suspicious user: C23 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C23 => DATA_EXFILTRATION
#     Found suspicious user: C23 => MALWARE_ALERT
#     Found suspicious user: C23 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C23 => MALWARE_ALERT
#     Found suspicious user: C23 => MALWARE_ALERT
#     Found suspicious user: C23 => DATA_EXFILTRATION
#     Found suspicious user: C23 => MALWARE_ALERT
#     Found suspicious user: C23 => DATA_EXFILTRATION
#     Found suspicious user: C23 => MALWARE_ALERT
#     Found suspicious user: C23 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C23 => MALWARE_ALERT
#     Found suspicious user: C23 => MALWARE_ALERT
#     Found suspicious user: C23 => MALWARE_ALERT
#     Found suspicious user: C23 => DATA_EXFILTRATION
#     Found suspicious user: C23 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C23 => DATA_EXFILTRATION
#     Found suspicious user: C23 => DATA_EXFILTRATION
#     Found suspicious user: C23 => DATA_EXFILTRATION
#     Found suspicious user: C23 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C23 => DATA_EXFILTRATION
#     Found suspicious user: C23 => MALWARE_ALERT
#     Found suspicious user: C23 => DATA_EXFILTRATION
#     Found suspicious user: C23 => DATA_EXFILTRATION
#     Found suspicious user: C23 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C23 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C23 => DATA_EXFILTRATION
#     Found suspicious user: C23 => MALWARE_ALERT
#     Found suspicious user: C23 => DATA_EXFILTRATION
#     Found suspicious user: C23 => MALWARE_ALERT
#     Found suspicious user: C23 => MALWARE_ALERT
#     Found suspicious user: C23 => DATA_EXFILTRATION
#     Found suspicious user: C23 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C23 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C23 => DATA_EXFILTRATION
#     Found suspicious user: C23 => MALWARE_ALERT
#     Found suspicious user: C23 => MALWARE_ALERT
#     Found suspicious user: C23 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C23 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C23 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C23 => DATA_EXFILTRATION
#     Found suspicious user: C23 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C23 => MALWARE_ALERT
#     Found suspicious user: C23 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C23 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C9 => DATA_EXFILTRATION
#     Found suspicious user: C9 => DATA_EXFILTRATION
#     Found suspicious user: C9 => MALWARE_ALERT
#     Found suspicious user: C9 => DATA_EXFILTRATION
#     Found suspicious user: C9 => MALWARE_ALERT
#     Found suspicious user: C9 => DATA_EXFILTRATION
#     Found suspicious user: C9 => DATA_EXFILTRATION
#     Found suspicious user: C9 => DATA_EXFILTRATION
#     Found suspicious user: C9 => MALWARE_ALERT
#     Found suspicious user: C9 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C9 => DATA_EXFILTRATION
#     Found suspicious user: C9 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C9 => DATA_EXFILTRATION
#     Found suspicious user: C9 => DATA_EXFILTRATION
#     Found suspicious user: C9 => DATA_EXFILTRATION
#     Found suspicious user: C9 => DATA_EXFILTRATION
#     Found suspicious user: C9 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C9 => DATA_EXFILTRATION
#     Found suspicious user: C9 => MALWARE_ALERT
#     Found suspicious user: C9 => MALWARE_ALERT
#     Found suspicious user: C9 => MALWARE_ALERT
#     Found suspicious user: C9 => MALWARE_ALERT
#     Found suspicious user: C9 => DATA_EXFILTRATION
#     Found suspicious user: C9 => MALWARE_ALERT
#     Found suspicious user: C9 => MALWARE_ALERT
#     Found suspicious user: C9 => DATA_EXFILTRATION
#     Found suspicious user: C9 => DATA_EXFILTRATION
#     Found suspicious user: C22 => MALWARE_ALERT
#     Found suspicious user: C22 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C22 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C22 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C22 => MALWARE_ALERT
#     Found suspicious user: C22 => MALWARE_ALERT
#     Found suspicious user: C22 => DATA_EXFILTRATION
#     Found suspicious user: C22 => MALWARE_ALERT
#     Found suspicious user: C22 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C22 => MALWARE_ALERT
#     Found suspicious user: C22 => MALWARE_ALERT
#     Found suspicious user: C22 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C22 => DATA_EXFILTRATION
#     Found suspicious user: C22 => MALWARE_ALERT
#     Found suspicious user: C22 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C22 => MALWARE_ALERT
#     Found suspicious user: C22 => DATA_EXFILTRATION
#     Found suspicious user: C22 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C22 => DATA_EXFILTRATION
#     Found suspicious user: C22 => MALWARE_ALERT
#     Found suspicious user: C22 => DATA_EXFILTRATION
#     Found suspicious user: C22 => MALWARE_ALERT
#     Found suspicious user: C22 => DATA_EXFILTRATION
#     Found suspicious user: C22 => DATA_EXFILTRATION
#     Found suspicious user: C22 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C22 => MALWARE_ALERT
#     Found suspicious user: C22 => MALWARE_ALERT
#     Found suspicious user: C22 => MALWARE_ALERT
#     Found suspicious user: C22 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C22 => MALWARE_ALERT
#     Found suspicious user: C22 => DATA_EXFILTRATION
#     Found suspicious user: C22 => DATA_EXFILTRATION
#     Found suspicious user: C22 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C22 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C22 => DATA_EXFILTRATION
#     Found suspicious user: C35 => DATA_EXFILTRATION
#     Found suspicious user: C35 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C35 => DATA_EXFILTRATION
#     Found suspicious user: C35 => DATA_EXFILTRATION
#     Found suspicious user: C35 => MALWARE_ALERT
#     Found suspicious user: C35 => DATA_EXFILTRATION
#     Found suspicious user: C35 => DATA_EXFILTRATION
#     Found suspicious user: C35 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C35 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C35 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C35 => DATA_EXFILTRATION
#     Found suspicious user: C35 => DATA_EXFILTRATION
#     Found suspicious user: C35 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C35 => MALWARE_ALERT
#     Found suspicious user: C35 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C35 => DATA_EXFILTRATION
#     Found suspicious user: C35 => MALWARE_ALERT
#     Found suspicious user: C35 => DATA_EXFILTRATION
#     Found suspicious user: C35 => MALWARE_ALERT
#     Found suspicious user: C35 => DATA_EXFILTRATION
#     Found suspicious user: C35 => DATA_EXFILTRATION
#     Found suspicious user: C35 => MALWARE_ALERT
#     Found suspicious user: C35 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C35 => MALWARE_ALERT
#     Found suspicious user: C35 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C35 => MALWARE_ALERT
#     Found suspicious user: C35 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C35 => DATA_EXFILTRATION
#     Found suspicious user: C35 => MALWARE_ALERT
#     Found suspicious user: C35 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C35 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C31 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C31 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C31 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C31 => DATA_EXFILTRATION
#     Found suspicious user: C31 => MALWARE_ALERT
#     Found suspicious user: C31 => DATA_EXFILTRATION
#     Found suspicious user: C31 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C31 => DATA_EXFILTRATION
#     Found suspicious user: C31 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C31 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C31 => MALWARE_ALERT
#     Found suspicious user: C31 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C31 => MALWARE_ALERT
#     Found suspicious user: C31 => MALWARE_ALERT
#     Found suspicious user: C31 => DATA_EXFILTRATION
#     Found suspicious user: C31 => DATA_EXFILTRATION
#     Found suspicious user: C31 => DATA_EXFILTRATION
#     Found suspicious user: C31 => DATA_EXFILTRATION
#     Found suspicious user: C31 => DATA_EXFILTRATION
#     Found suspicious user: C31 => MALWARE_ALERT
#     Found suspicious user: C31 => MALWARE_ALERT
#     Found suspicious user: C31 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C31 => MALWARE_ALERT
#     Found suspicious user: C45 => DATA_EXFILTRATION
#     Found suspicious user: C45 => MALWARE_ALERT
#     Found suspicious user: C45 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C45 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C45 => DATA_EXFILTRATION
#     Found suspicious user: C45 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C45 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C45 => MALWARE_ALERT
#     Found suspicious user: C45 => DATA_EXFILTRATION
#     Found suspicious user: C45 => MALWARE_ALERT
#     Found suspicious user: C45 => MALWARE_ALERT
#     Found suspicious user: C45 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C45 => DATA_EXFILTRATION
#     Found suspicious user: C45 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C45 => DATA_EXFILTRATION
#     Found suspicious user: C45 => MALWARE_ALERT
#     Found suspicious user: C45 => MALWARE_ALERT
#     Found suspicious user: C45 => DATA_EXFILTRATION
#     Found suspicious user: C45 => MALWARE_ALERT
#     Found suspicious user: C45 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C45 => MALWARE_ALERT
#     Found suspicious user: C45 => DATA_EXFILTRATION
#     Found suspicious user: C45 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C45 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C45 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C45 => DATA_EXFILTRATION
#     Found suspicious user: C45 => DATA_EXFILTRATION
#     Found suspicious user: C45 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C45 => DATA_EXFILTRATION
#     Found suspicious user: C45 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C45 => DATA_EXFILTRATION
#     Found suspicious user: C6 => DATA_EXFILTRATION
#     Found suspicious user: C6 => MALWARE_ALERT
#     Found suspicious user: C6 => MALWARE_ALERT
#     Found suspicious user: C6 => DATA_EXFILTRATION
#     Found suspicious user: C6 => DATA_EXFILTRATION
#     Found suspicious user: C6 => DATA_EXFILTRATION
#     Found suspicious user: C6 => DATA_EXFILTRATION
#     Found suspicious user: C6 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C6 => MALWARE_ALERT
#     Found suspicious user: C6 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C6 => MALWARE_ALERT
#     Found suspicious user: C6 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C6 => DATA_EXFILTRATION
#     Found suspicious user: C6 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C6 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C6 => MALWARE_ALERT
#     Found suspicious user: C6 => MALWARE_ALERT
#     Found suspicious user: C6 => DATA_EXFILTRATION
#     Found suspicious user: C6 => MALWARE_ALERT
#     Found suspicious user: C6 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C6 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C6 => DATA_EXFILTRATION
#     Found suspicious user: C6 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C6 => MALWARE_ALERT
#     Found suspicious user: C6 => DATA_EXFILTRATION
#     Found suspicious user: C6 => DATA_EXFILTRATION
#     Found suspicious user: C6 => MALWARE_ALERT
#     Found suspicious user: C6 => MALWARE_ALERT
#     Found suspicious user: C6 => DATA_EXFILTRATION
#     Found suspicious user: C6 => MALWARE_ALERT
#     Found suspicious user: C6 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C6 => MALWARE_ALERT
#     Found suspicious user: C6 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C6 => MALWARE_ALERT
#     Found suspicious user: C6 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C3 => MALWARE_ALERT
#     Found suspicious user: C3 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C3 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C3 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C3 => MALWARE_ALERT
#     Found suspicious user: C3 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C3 => MALWARE_ALERT
#     Found suspicious user: C3 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C3 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C3 => MALWARE_ALERT
#     Found suspicious user: C3 => MALWARE_ALERT
#     Found suspicious user: C3 => DATA_EXFILTRATION
#     Found suspicious user: C3 => MALWARE_ALERT
#     Found suspicious user: C3 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C3 => DATA_EXFILTRATION
#     Found suspicious user: C3 => DATA_EXFILTRATION
#     Found suspicious user: C3 => DATA_EXFILTRATION
#     Found suspicious user: C3 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C3 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C3 => DATA_EXFILTRATION
#     Found suspicious user: C3 => MALWARE_ALERT
#     Found suspicious user: C3 => DATA_EXFILTRATION
#     Found suspicious user: C3 => DATA_EXFILTRATION
#     Found suspicious user: C3 => MALWARE_ALERT
#     Found suspicious user: C3 => DATA_EXFILTRATION
#     Found suspicious user: C3 => MALWARE_ALERT
#     Found suspicious user: C7 => DATA_EXFILTRATION
#     Found suspicious user: C7 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C7 => DATA_EXFILTRATION
#     Found suspicious user: C7 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C7 => DATA_EXFILTRATION
#     Found suspicious user: C7 => MALWARE_ALERT
#     Found suspicious user: C7 => DATA_EXFILTRATION
#     Found suspicious user: C7 => DATA_EXFILTRATION
#     Found suspicious user: C7 => MALWARE_ALERT
#     Found suspicious user: C7 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C7 => DATA_EXFILTRATION
#     Found suspicious user: C7 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C7 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C7 => MALWARE_ALERT
#     Found suspicious user: C7 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C7 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C7 => DATA_EXFILTRATION
#     Found suspicious user: C7 => MALWARE_ALERT
#     Found suspicious user: C7 => DATA_EXFILTRATION
#     Found suspicious user: C7 => DATA_EXFILTRATION
#     Found suspicious user: C7 => DATA_EXFILTRATION
#     Found suspicious user: C7 => DATA_EXFILTRATION
#     Found suspicious user: C7 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C7 => DATA_EXFILTRATION
#     Found suspicious user: C7 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C13 => MALWARE_ALERT
#     Found suspicious user: C13 => DATA_EXFILTRATION
#     Found suspicious user: C13 => MALWARE_ALERT
#     Found suspicious user: C13 => DATA_EXFILTRATION
#     Found suspicious user: C13 => MALWARE_ALERT
#     Found suspicious user: C13 => MALWARE_ALERT
#     Found suspicious user: C13 => MALWARE_ALERT
#     Found suspicious user: C13 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C13 => MALWARE_ALERT
#     Found suspicious user: C13 => MALWARE_ALERT
#     Found suspicious user: C13 => MALWARE_ALERT
#     Found suspicious user: C13 => DATA_EXFILTRATION
#     Found suspicious user: C13 => DATA_EXFILTRATION
#     Found suspicious user: C13 => MALWARE_ALERT
#     Found suspicious user: C13 => MALWARE_ALERT
#     Found suspicious user: C13 => DATA_EXFILTRATION
#     Found suspicious user: C13 => DATA_EXFILTRATION
#     Found suspicious user: C13 => DATA_EXFILTRATION
#     Found suspicious user: C13 => DATA_EXFILTRATION
#     Found suspicious user: C13 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C13 => DATA_EXFILTRATION
#     Found suspicious user: C13 => MALWARE_ALERT
#     Found suspicious user: C13 => DATA_EXFILTRATION
#     Found suspicious user: C13 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C13 => MALWARE_ALERT
#     Found suspicious user: C13 => DATA_EXFILTRATION
#     Found suspicious user: C13 => MALWARE_ALERT
#     Found suspicious user: C13 => MALWARE_ALERT
#     Found suspicious user: C1 => MALWARE_ALERT
#     Found suspicious user: C1 => DATA_EXFILTRATION
#     Found suspicious user: C1 => MALWARE_ALERT
#     Found suspicious user: C1 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C1 => MALWARE_ALERT
#     Found suspicious user: C1 => DATA_EXFILTRATION
#     Found suspicious user: C1 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C1 => DATA_EXFILTRATION
#     Found suspicious user: C1 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C1 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C1 => DATA_EXFILTRATION
#     Found suspicious user: C1 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C1 => DATA_EXFILTRATION
#     Found suspicious user: C1 => DATA_EXFILTRATION
#     Found suspicious user: C1 => DATA_EXFILTRATION
#     Found suspicious user: C1 => MALWARE_ALERT
#     Found suspicious user: C1 => MALWARE_ALERT
#     Found suspicious user: C1 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C1 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C1 => MALWARE_ALERT
#     Found suspicious user: C1 => MALWARE_ALERT
#     Found suspicious user: C1 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C1 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C1 => MALWARE_ALERT
#     Found suspicious user: C1 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C1 => DATA_EXFILTRATION
#     Found suspicious user: C1 => DATA_EXFILTRATION
#     Found suspicious user: C1 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C1 => MALWARE_ALERT
#     Found suspicious user: C1 => DATA_EXFILTRATION
#     Found suspicious user: C1 => MALWARE_ALERT
#     Found suspicious user: C1 => DATA_EXFILTRATION
#     Found suspicious user: C1 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C1 => DATA_EXFILTRATION
#     Found suspicious user: C1 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C46 => DATA_EXFILTRATION
#     Found suspicious user: C46 => DATA_EXFILTRATION
#     Found suspicious user: C46 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C46 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C46 => MALWARE_ALERT
#     Found suspicious user: C46 => MALWARE_ALERT
#     Found suspicious user: C46 => MALWARE_ALERT
#     Found suspicious user: C46 => MALWARE_ALERT
#     Found suspicious user: C46 => DATA_EXFILTRATION
#     Found suspicious user: C46 => DATA_EXFILTRATION
#     Found suspicious user: C46 => MALWARE_ALERT
#     Found suspicious user: C46 => DATA_EXFILTRATION
#     Found suspicious user: C46 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C46 => MALWARE_ALERT
#     Found suspicious user: C46 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C46 => DATA_EXFILTRATION
#     Found suspicious user: C46 => MALWARE_ALERT
#     Found suspicious user: C46 => DATA_EXFILTRATION
#     Found suspicious user: C46 => MALWARE_ALERT
#     Found suspicious user: C46 => DATA_EXFILTRATION
#     Found suspicious user: C46 => DATA_EXFILTRATION
#     Found suspicious user: C46 => DATA_EXFILTRATION
#     Found suspicious user: C46 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C46 => MALWARE_ALERT
#     Found suspicious user: C46 => DATA_EXFILTRATION
#     Found suspicious user: C46 => MALWARE_ALERT
#     Found suspicious user: C46 => MALWARE_ALERT
#     Found suspicious user: C49 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C49 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C49 => MALWARE_ALERT
#     Found suspicious user: C49 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C49 => DATA_EXFILTRATION
#     Found suspicious user: C49 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C49 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C49 => DATA_EXFILTRATION
#     Found suspicious user: C49 => MALWARE_ALERT
#     Found suspicious user: C49 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C49 => DATA_EXFILTRATION
#     Found suspicious user: C49 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C49 => DATA_EXFILTRATION
#     Found suspicious user: C49 => DATA_EXFILTRATION
#     Found suspicious user: C49 => MALWARE_ALERT
#     Found suspicious user: C49 => MALWARE_ALERT
#     Found suspicious user: C49 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C49 => MALWARE_ALERT
#     Found suspicious user: C49 => DATA_EXFILTRATION
#     Found suspicious user: C49 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C49 => DATA_EXFILTRATION
#     Found suspicious user: C49 => DATA_EXFILTRATION
#     Found suspicious user: C49 => DATA_EXFILTRATION
#     Found suspicious user: C49 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C49 => DATA_EXFILTRATION
#     Found suspicious user: C49 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C49 => MALWARE_ALERT
#     Found suspicious user: C49 => DATA_EXFILTRATION
#     Found suspicious user: C49 => DATA_EXFILTRATION
#     Found suspicious user: C49 => DATA_EXFILTRATION
#     Found suspicious user: C49 => MALWARE_ALERT
#     Found suspicious user: C49 => MALWARE_ALERT
#     Found suspicious user: C49 => DATA_EXFILTRATION
#     Found suspicious user: C17 => MALWARE_ALERT
#     Found suspicious user: C17 => DATA_EXFILTRATION
#     Found suspicious user: C17 => MALWARE_ALERT
#     Found suspicious user: C17 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C17 => MALWARE_ALERT
#     Found suspicious user: C17 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C17 => MALWARE_ALERT
#     Found suspicious user: C17 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C17 => MALWARE_ALERT
#     Found suspicious user: C17 => MALWARE_ALERT
#     Found suspicious user: C17 => DATA_EXFILTRATION
#     Found suspicious user: C17 => DATA_EXFILTRATION
#     Found suspicious user: C17 => MALWARE_ALERT
#     Found suspicious user: C17 => DATA_EXFILTRATION
#     Found suspicious user: C17 => MALWARE_ALERT
#     Found suspicious user: C17 => DATA_EXFILTRATION
#     Found suspicious user: C17 => DATA_EXFILTRATION
#     Found suspicious user: C17 => MALWARE_ALERT
#     Found suspicious user: C17 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C17 => DATA_EXFILTRATION
#     Found suspicious user: C17 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C17 => DATA_EXFILTRATION
#     Found suspicious user: C17 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C17 => DATA_EXFILTRATION
#     Found suspicious user: C17 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C17 => DATA_EXFILTRATION
#     Found suspicious user: C17 => MALWARE_ALERT
#     Found suspicious user: C17 => MALWARE_ALERT
#     Found suspicious user: C17 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C17 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C2 => DATA_EXFILTRATION
#     Found suspicious user: C2 => DATA_EXFILTRATION
#     Found suspicious user: C2 => DATA_EXFILTRATION
#     Found suspicious user: C2 => MALWARE_ALERT
#     Found suspicious user: C2 => DATA_EXFILTRATION
#     Found suspicious user: C2 => DATA_EXFILTRATION
#     Found suspicious user: C2 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C2 => MALWARE_ALERT
#     Found suspicious user: C2 => DATA_EXFILTRATION
#     Found suspicious user: C2 => DATA_EXFILTRATION
#     Found suspicious user: C2 => MALWARE_ALERT
#     Found suspicious user: C2 => MALWARE_ALERT
#     Found suspicious user: C2 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C2 => DATA_EXFILTRATION
#     Found suspicious user: C2 => MALWARE_ALERT
#     Found suspicious user: C2 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C2 => DATA_EXFILTRATION
#     Found suspicious user: C2 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C2 => DATA_EXFILTRATION
#     Found suspicious user: C2 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C2 => DATA_EXFILTRATION
#     Found suspicious user: C2 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C2 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C2 => MALWARE_ALERT
#     Found suspicious user: C32 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C32 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C32 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C32 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C32 => DATA_EXFILTRATION
#     Found suspicious user: C32 => MALWARE_ALERT
#     Found suspicious user: C32 => MALWARE_ALERT
#     Found suspicious user: C32 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C32 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C32 => DATA_EXFILTRATION
#     Found suspicious user: C32 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C32 => DATA_EXFILTRATION
#     Found suspicious user: C32 => MALWARE_ALERT
#     Found suspicious user: C32 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C32 => MALWARE_ALERT
#     Found suspicious user: C32 => MALWARE_ALERT
#     Found suspicious user: C32 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C32 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C32 => DATA_EXFILTRATION
#     Found suspicious user: C32 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C32 => DATA_EXFILTRATION
#     Found suspicious user: C32 => DATA_EXFILTRATION
#     Found suspicious user: C32 => MALWARE_ALERT
#     Found suspicious user: C32 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C32 => DATA_EXFILTRATION
#     Found suspicious user: C32 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C32 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C32 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C32 => MALWARE_ALERT
#     Found suspicious user: C32 => DATA_EXFILTRATION
#     Found suspicious user: C32 => MALWARE_ALERT
#     Found suspicious user: C32 => DATA_EXFILTRATION
#     Found suspicious user: C32 => MALWARE_ALERT
#     Found suspicious user: C32 => DATA_EXFILTRATION
#     Found suspicious user: C32 => MALWARE_ALERT
#     Found suspicious user: C32 => DATA_EXFILTRATION
#     Found suspicious user: C38 => MALWARE_ALERT
#     Found suspicious user: C38 => MALWARE_ALERT
#     Found suspicious user: C38 => DATA_EXFILTRATION
#     Found suspicious user: C38 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C38 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C38 => MALWARE_ALERT
#     Found suspicious user: C38 => MALWARE_ALERT
#     Found suspicious user: C38 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C38 => MALWARE_ALERT
#     Found suspicious user: C38 => MALWARE_ALERT
#     Found suspicious user: C38 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C38 => DATA_EXFILTRATION
#     Found suspicious user: C38 => MALWARE_ALERT
#     Found suspicious user: C38 => MALWARE_ALERT
#     Found suspicious user: C38 => DATA_EXFILTRATION
#     Found suspicious user: C38 => MALWARE_ALERT
#     Found suspicious user: C38 => DATA_EXFILTRATION
#     Found suspicious user: C38 => MALWARE_ALERT
#     Found suspicious user: C38 => DATA_EXFILTRATION
# ...
#     Found suspicious user: C28 => DATA_EXFILTRATION
#     Found suspicious user: C28 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C28 => MALWARE_ALERT
#     Found suspicious user: C28 => MALWARE_ALERT
#     Found suspicious user: C28 => MALWARE_ALERT
#     Found suspicious user: C28 => DATA_EXFILTRATION
#     Found suspicious user: C28 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C28 => DATA_EXFILTRATION
#     Found suspicious user: C28 => DATA_EXFILTRATION
#     Found suspicious user: C44 => MALWARE_ALERT
#     Found suspicious user: C44 => MALWARE_ALERT
#     Found suspicious user: C44 => DATA_EXFILTRATION
#     Found suspicious user: C44 => DATA_EXFILTRATION
#     Found suspicious user: C44 => DATA_EXFILTRATION
#     Found suspicious user: C44 => MALWARE_ALERT
#     Found suspicious user: C44 => DATA_EXFILTRATION
#     Found suspicious user: C44 => DATA_EXFILTRATION
#     Found suspicious user: C44 => DATA_EXFILTRATION
#     Found suspicious user: C44 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C44 => MALWARE_ALERT
#     Found suspicious user: C44 => MALWARE_ALERT
#     Found suspicious user: C44 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C44 => MALWARE_ALERT
#     Found suspicious user: C44 => DATA_EXFILTRATION
#     Found suspicious user: C44 => DATA_EXFILTRATION
#     Found suspicious user: C44 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C44 => DATA_EXFILTRATION
#     Found suspicious user: C44 => DATA_EXFILTRATION
#     Found suspicious user: C44 => MALWARE_ALERT
#     Found suspicious user: C44 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C44 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C44 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C44 => MALWARE_ALERT
#     Found suspicious user: C44 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C44 => DATA_EXFILTRATION
#     Found suspicious user: C44 => DATA_EXFILTRATION
#     Found suspicious user: C44 => MALWARE_ALERT
#     Found suspicious user: C44 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C44 => DATA_EXFILTRATION
#     Found suspicious user: C44 => DATA_EXFILTRATION
#     Found suspicious user: C44 => MALWARE_ALERT
#     Found suspicious user: C44 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C44 => DATA_EXFILTRATION
#     Found suspicious user: C47 => DATA_EXFILTRATION
#     Found suspicious user: C47 => MALWARE_ALERT
#     Found suspicious user: C47 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C47 => DATA_EXFILTRATION
#     Found suspicious user: C47 => MALWARE_ALERT
#     Found suspicious user: C47 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C47 => DATA_EXFILTRATION
#     Found suspicious user: C47 => MALWARE_ALERT
#     Found suspicious user: C47 => DATA_EXFILTRATION
#     Found suspicious user: C47 => DATA_EXFILTRATION
#     Found suspicious user: C47 => DATA_EXFILTRATION
#     Found suspicious user: C47 => MALWARE_ALERT
#     Found suspicious user: C47 => DATA_EXFILTRATION
#     Found suspicious user: C47 => DATA_EXFILTRATION
#     Found suspicious user: C47 => MALWARE_ALERT
#     Found suspicious user: C47 => DATA_EXFILTRATION
#     Found suspicious user: C47 => DATA_EXFILTRATION
#     Found suspicious user: C47 => DATA_EXFILTRATION
#     Found suspicious user: C47 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C47 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C47 => DATA_EXFILTRATION
#     Found suspicious user: C47 => DATA_EXFILTRATION
#     Found suspicious user: C47 => MALWARE_ALERT
#     Found suspicious user: C47 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C47 => MALWARE_ALERT
#     Found suspicious user: C47 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C47 => MALWARE_ALERT
#     Found suspicious user: C47 => MALWARE_ALERT
#     Found suspicious user: C47 => DATA_EXFILTRATION
#     Found suspicious user: C47 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C47 => MALWARE_ALERT
#     Found suspicious user: C47 => MALWARE_ALERT
#     Found suspicious user: C47 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C47 => MALWARE_ALERT
#     Found suspicious user: C47 => MALWARE_ALERT
#     Found suspicious user: C47 => MALWARE_ALERT
#     Found suspicious user: C47 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C47 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C47 => DATA_EXFILTRATION
#     Found suspicious user: C47 => MALWARE_ALERT
#     Found suspicious user: C47 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C29 => DATA_EXFILTRATION
#     Found suspicious user: C29 => MALWARE_ALERT
#     Found suspicious user: C29 => MALWARE_ALERT
#     Found suspicious user: C29 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C29 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C29 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C29 => MALWARE_ALERT
#     Found suspicious user: C29 => MALWARE_ALERT
#     Found suspicious user: C29 => DATA_EXFILTRATION
#     Found suspicious user: C29 => MALWARE_ALERT
#     Found suspicious user: C29 => MALWARE_ALERT
#     Found suspicious user: C29 => MALWARE_ALERT
#     Found suspicious user: C29 => MALWARE_ALERT
#     Found suspicious user: C29 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C29 => MALWARE_ALERT
#     Found suspicious user: C29 => MALWARE_ALERT
#     Found suspicious user: C29 => DATA_EXFILTRATION
#     Found suspicious user: C29 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C29 => DATA_EXFILTRATION
#     Found suspicious user: C29 => MALWARE_ALERT
#     Found suspicious user: C29 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C29 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C29 => MALWARE_ALERT
#     Found suspicious user: C29 => MALWARE_ALERT
#     Found suspicious user: C29 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C29 => MALWARE_ALERT
#     Found suspicious user: C29 => MALWARE_ALERT
#     Found suspicious user: C29 => MALWARE_ALERT
#     Found suspicious user: C29 => MALWARE_ALERT
#     Found suspicious user: C41 => MALWARE_ALERT
#     Found suspicious user: C41 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C41 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C41 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C41 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C41 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C41 => DATA_EXFILTRATION
#     Found suspicious user: C41 => MALWARE_ALERT
#     Found suspicious user: C41 => DATA_EXFILTRATION
#     Found suspicious user: C41 => DATA_EXFILTRATION
#     Found suspicious user: C41 => DATA_EXFILTRATION
#     Found suspicious user: C41 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C41 => MALWARE_ALERT
#     Found suspicious user: C41 => DATA_EXFILTRATION
#     Found suspicious user: C41 => DATA_EXFILTRATION
#     Found suspicious user: C41 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C41 => DATA_EXFILTRATION
#     Found suspicious user: C41 => DATA_EXFILTRATION
#     Found suspicious user: C41 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C41 => MALWARE_ALERT
#     Found suspicious user: C41 => MALWARE_ALERT
#     Found suspicious user: C41 => DATA_EXFILTRATION
#     Found suspicious user: C41 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C41 => MALWARE_ALERT
#     Found suspicious user: C41 => DATA_EXFILTRATION
#     Found suspicious user: C41 => MALWARE_ALERT
#     Found suspicious user: C41 => MALWARE_ALERT
#     Found suspicious user: C19 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C19 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C19 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C19 => DATA_EXFILTRATION
#     Found suspicious user: C19 => DATA_EXFILTRATION
#     Found suspicious user: C19 => MALWARE_ALERT
#     Found suspicious user: C19 => MALWARE_ALERT
#     Found suspicious user: C19 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C19 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C19 => MALWARE_ALERT
#     Found suspicious user: C19 => MALWARE_ALERT
#     Found suspicious user: C19 => MALWARE_ALERT
#     Found suspicious user: C19 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C19 => DATA_EXFILTRATION
#     Found suspicious user: C19 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C19 => MALWARE_ALERT
#     Found suspicious user: C19 => MALWARE_ALERT
#     Found suspicious user: C19 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C19 => DATA_EXFILTRATION
#     Found suspicious user: C19 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C19 => MALWARE_ALERT
#     Found suspicious user: C19 => MALWARE_ALERT
#     Found suspicious user: C19 => DATA_EXFILTRATION
#     Found suspicious user: C19 => MALWARE_ALERT
#     Found suspicious user: C19 => MALWARE_ALERT
#     Found suspicious user: C19 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C19 => DATA_EXFILTRATION
#     Found suspicious user: C19 => MALWARE_ALERT
#     Found suspicious user: C24 => DATA_EXFILTRATION
#     Found suspicious user: C24 => MALWARE_ALERT
#     Found suspicious user: C24 => DATA_EXFILTRATION
#     Found suspicious user: C24 => DATA_EXFILTRATION
#     Found suspicious user: C24 => MALWARE_ALERT
#     Found suspicious user: C24 => DATA_EXFILTRATION
#     Found suspicious user: C24 => DATA_EXFILTRATION
#     Found suspicious user: C24 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C24 => DATA_EXFILTRATION
#     Found suspicious user: C24 => MALWARE_ALERT
#     Found suspicious user: C24 => DATA_EXFILTRATION
#     Found suspicious user: C24 => MALWARE_ALERT
#     Found suspicious user: C24 => DATA_EXFILTRATION
#     Found suspicious user: C24 => DATA_EXFILTRATION
#     Found suspicious user: C24 => DATA_EXFILTRATION
#     Found suspicious user: C24 => DATA_EXFILTRATION
#     Found suspicious user: C24 => DATA_EXFILTRATION
#     Found suspicious user: C24 => MALWARE_ALERT
#     Found suspicious user: C24 => DATA_EXFILTRATION
#     Found suspicious user: C24 => MALWARE_ALERT
#     Found suspicious user: C24 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C24 => MALWARE_ALERT
#     Found suspicious user: C24 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C24 => MALWARE_ALERT
#     Found suspicious user: C24 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C33 => DATA_EXFILTRATION
#     Found suspicious user: C33 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C33 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C33 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C33 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C33 => MALWARE_ALERT
#     Found suspicious user: C33 => DATA_EXFILTRATION
#     Found suspicious user: C33 => DATA_EXFILTRATION
#     Found suspicious user: C33 => MALWARE_ALERT
#     Found suspicious user: C33 => MALWARE_ALERT
#     Found suspicious user: C33 => DATA_EXFILTRATION
#     Found suspicious user: C33 => MALWARE_ALERT
#     Found suspicious user: C33 => DATA_EXFILTRATION
#     Found suspicious user: C33 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C33 => MALWARE_ALERT
#     Found suspicious user: C33 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C33 => MALWARE_ALERT
#     Found suspicious user: C33 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C33 => MALWARE_ALERT
#     Found suspicious user: C33 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C33 => DATA_EXFILTRATION
#     Found suspicious user: C33 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C33 => DATA_EXFILTRATION
#     Found suspicious user: C33 => DATA_EXFILTRATION
#     Found suspicious user: C33 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C33 => MALWARE_ALERT
#     Found suspicious user: C33 => DATA_EXFILTRATION
#     Found suspicious user: C33 => DATA_EXFILTRATION
#     Found suspicious user: C33 => DATA_EXFILTRATION
#     Found suspicious user: C33 => DATA_EXFILTRATION
#     Found suspicious user: C33 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C39 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C39 => DATA_EXFILTRATION
#     Found suspicious user: C39 => MALWARE_ALERT
#     Found suspicious user: C39 => MALWARE_ALERT
#     Found suspicious user: C39 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C39 => DATA_EXFILTRATION
#     Found suspicious user: C39 => DATA_EXFILTRATION
#     Found suspicious user: C39 => MALWARE_ALERT
#     Found suspicious user: C39 => MALWARE_ALERT
#     Found suspicious user: C39 => MALWARE_ALERT
#     Found suspicious user: C39 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C39 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C39 => MALWARE_ALERT
#     Found suspicious user: C39 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C39 => MALWARE_ALERT
#     Found suspicious user: C39 => DATA_EXFILTRATION
#     Found suspicious user: C39 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C39 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C39 => DATA_EXFILTRATION
#     Found suspicious user: C39 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C39 => MALWARE_ALERT
#     Found suspicious user: C39 => DATA_EXFILTRATION
#     Found suspicious user: C39 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C39 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C39 => DATA_EXFILTRATION
#     Found suspicious user: C39 => DATA_EXFILTRATION
#     Found suspicious user: C39 => MALWARE_ALERT
#     Found suspicious user: C39 => DATA_EXFILTRATION
#     Found suspicious user: C39 => MALWARE_ALERT
#     Found suspicious user: C39 => MALWARE_ALERT
#     Found suspicious user: C39 => MALWARE_ALERT
#     Found suspicious user: C42 => DATA_EXFILTRATION
#     Found suspicious user: C42 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C42 => DATA_EXFILTRATION
#     Found suspicious user: C42 => DATA_EXFILTRATION
#     Found suspicious user: C42 => MALWARE_ALERT
#     Found suspicious user: C42 => DATA_EXFILTRATION
#     Found suspicious user: C42 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C42 => MALWARE_ALERT
#     Found suspicious user: C42 => DATA_EXFILTRATION
#     Found suspicious user: C42 => DATA_EXFILTRATION
#     Found suspicious user: C42 => DATA_EXFILTRATION
#     Found suspicious user: C42 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C42 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C42 => MALWARE_ALERT
#     Found suspicious user: C42 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C42 => MALWARE_ALERT
#     Found suspicious user: C42 => MALWARE_ALERT
#     Found suspicious user: C42 => DATA_EXFILTRATION
#     Found suspicious user: C42 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C42 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C42 => MALWARE_ALERT
#     Found suspicious user: C42 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C42 => MALWARE_ALERT
#     Found suspicious user: C42 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C42 => UNAUTHORIZED_ACCESS
#     Found suspicious user: C42 => MALWARE_ALERT
#     Found suspicious user: C42 => MALWARE_ALERT
# Processing user: C18
# Processing user: C4
# Processing user: C12
# Processing user: C16
# Processing user: C40
# Processing user: C48
# Processing user: C34
# Processing user: C21
# Processing user: C14
# Processing user: C36
# Processing user: C25
# Processing user: C37
# Processing user: C5
# Processing user: C8
# Processing user: C23
# Processing user: C9
# Processing user: C22
# Processing user: C35
# Processing user: C31
# Processing user: C45
# Processing user: C6
# Processing user: C3
# Processing user: C7
# Processing user: C13
# Processing user: C1
# Processing user: C46
# Processing user: C49
# Processing user: C17
# Processing user: C2
# Processing user: C32
# Processing user: C38
# Processing user: C50
# Processing user: C43
# Processing user: C10
# Processing user: C26
# Processing user: C11
# Processing user: C30
# Processing user: C27
# Processing user: C15
# Processing user: C20
# Processing user: C28
# Processing user: C44
# Processing user: C47
# Processing user: C29
# Processing user: C41
# Processing user: C19
# Processing user: C24
# Processing user: C33
# Processing user: C39
# Processing user: C42
#
# Suspicious users: {'C34', 'C16', 'C48', 'C47', 'C17', 'C42', 'C25', 'C5', 'C35', 'C3', 'C11', 'C31', 'C29', 'C37', 'C49', 'C50', 'C30', 'C18', 'C1', 'C22', 'C20', 'C23', 'C13', 'C39', 'C41', 'C44', 'C19', 'C32', 'C12', 'C2', 'C38', 'C36', 'C21', 'C6', 'U1', 'C15', 'C46', 'C40', 'C4', 'C8', 'C26', 'C43', 'C27', 'C33', 'C45', 'C9', 'C10', 'C28', 'C24', 'C14', 'C7'}
# Suspicious computers: {'C34', 'C18', 'C32', 'C17', 'C27', 'C36', 'C35', 'C24', 'C11', 'C3', 'C29', 'C40', 'C26', 'C49'}
